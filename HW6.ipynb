# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
house_data = pd.read_csv('kc_house_data.csv')
house_data = house_data.drop(columns=['id','zipcode'])

# %%
house_data
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      20141013T000000  221900.0         3       1.00         1180      5650
# 1      20141209T000000  538000.0         3       2.25         2570      7242
# 2      20150225T000000  180000.0         2       1.00          770     10000
# 3      20141209T000000  604000.0         4       3.00         1960      5000
# 4      20150218T000000  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 21608  20140521T000000  360000.0         3       2.50         1530      1131
# 21609  20150223T000000  400000.0         4       2.50         2310      5813
# 21610  20140623T000000  402101.0         2       0.75         1020      1350
# 21611  20150116T000000  400000.0         3       2.50         1600      2388
# 21612  20141015T000000  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0           0     0          3      7        1180              0
# 1         2.0           0     0          3      7        2170            400
# 2         1.0           0     0          3      6         770              0
# 3         1.0           0     0          5      7        1050            910
# 4         1.0           0     0          3      8        1680              0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21608     3.0           0     0          3      8        1530              0
# 21609     2.0           0     0          3      8        2310              0
# 21610     2.0           0     0          3      7        1020              0
# 21611     2.0           0     0          3      8        1600              0
# 21612     2.0           0     0          3      7        1020              0
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15
# 0          1955             0  47.5112 -122.257           1340        5650
# 1          1951          1991  47.7210 -122.319           1690        7639
# 2          1933             0  47.7379 -122.233           2720        8062
# 3          1965             0  47.5208 -122.393           1360        5000
# 4          1987             0  47.6168 -122.045           1800        7503
# ...         ...           ...      ...      ...            ...         ...
# 21608      2009             0  47.6993 -122.346           1530        1509
# 21609      2014             0  47.5107 -122.362           1830        7200
# 21610      2009             0  47.5944 -122.299           1020        2007
# 21611      2004             0  47.5345 -122.069           1410        1287
# 21612      2008             0  47.5941 -122.299           1020        1357
#
# [21613 rows x 19 columns]

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  lat            21613 non-null  float64
#  16  long           21613 non-null  float64
#  17  sqft_living15  21613 non-null  int64
#  18  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(13), object(1)
# memory usage: 3.1+ MB

# %%
# Change type of date
house_data['date'] = pd.to_datetime(house_data['date'])
house_data['year'] = house_data['date'].dt.year
house_data['month'] = house_data['date'].dt.month
house_data['day'] = house_data['date'].dt.day
house_data = house_data.drop(columns='date')

# %%
house_data
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      221900.0         3       1.00         1180      5650     1.0
# 1      538000.0         3       2.25         2570      7242     2.0
# 2      180000.0         2       1.00          770     10000     1.0
# 3      604000.0         4       3.00         1960      5000     1.0
# 4      510000.0         3       2.00         1680      8080     1.0
# ...         ...       ...        ...          ...       ...     ...
# 21608  360000.0         3       2.50         1530      1131     3.0
# 21609  400000.0         4       2.50         2310      5813     2.0
# 21610  402101.0         2       0.75         1020      1350     2.0
# 21611  400000.0         3       2.50         1600      2388     2.0
# 21612  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 0               0     0          3      7  ...              0      1955
# 1               0     0          3      7  ...            400      1951
# 2               0     0          3      6  ...              0      1933
# 3               0     0          5      7  ...            910      1965
# 4               0     0          3      8  ...              0      1987
# ...           ...   ...        ...    ...  ...            ...       ...
# 21608           0     0          3      8  ...              0      2009
# 21609           0     0          3      8  ...              0      2014
# 21610           0     0          3      7  ...              0      2009
# 21611           0     0          3      8  ...              0      2004
# 21612           0     0          3      7  ...              0      2008
#
#        yr_renovated      lat     long  sqft_living15  sqft_lot15  year  month  \
# 0                 0  47.5112 -122.257           1340        5650  2014     10
# 1              1991  47.7210 -122.319           1690        7639  2014     12
# 2                 0  47.7379 -122.233           2720        8062  2015      2
# 3                 0  47.5208 -122.393           1360        5000  2014     12
# 4                 0  47.6168 -122.045           1800        7503  2015      2
# ...             ...      ...      ...            ...         ...   ...    ...
# 21608             0  47.6993 -122.346           1530        1509  2014      5
# 21609             0  47.5107 -122.362           1830        7200  2015      2
# 21610             0  47.5944 -122.299           1020        2007  2014      6
# 21611             0  47.5345 -122.069           1410        1287  2015      1
# 21612             0  47.5941 -122.299           1020        1357  2014     10
#
#        day
# 0       13
# 1        9
# 2       25
# 3        9
# 4       18
# ...    ...
# 21608   21
# 21609   23
# 21610   23
# 21611   16
# 21612   15
#
# [21613 rows x 21 columns]

# %%
X = house_data.drop(columns = 'price')
y = house_data['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=0)

# %% [markdown]
# K-Nearest Neighbors

# %%
knn = KNeighborsRegressor()

# Siêu tham số cho KNN
param_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]  # Manhattan (p=1) và Euclidean (p=2)
}

grid_knn = GridSearchCV(knn, param_knn, cv=5)
grid_knn.fit(X_train, y_train)

print("Best parameters for KNN:", grid_knn.best_params_)
# Out:
# Best parameters for KNN: {'n_neighbors': 9, 'p': 1, 'weights': 'distance'}

# %% [markdown]
# Random Forest

# %%
rf = RandomForestRegressor(random_state=0)

param_rf = {
    'n_estimators': [100, 200],
    'max_depth': [None,30],
    'min_samples_split': [210],
    'min_samples_leaf': [1]
}

grid_rf = GridSearchCV(rf, param_rf, cv=5)
grid_rf.fit(X_train, y_train)

print("Best parameters for Random Forest:", grid_rf.best_params_)
# Out:
# Best parameters for Random Forest: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 210, 'n_estimators': 100}

# %% [markdown]
# Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Ridge Regression

# %%
ridge = Ridge()

param_ridge = {
    'alpha': [0.1, 1.0, 10.0, 100.0]
}

grid_ridge = GridSearchCV(ridge, param_ridge, cv=5)
grid_ridge.fit(X_train, y_train)

print("Best parameters for Ridge:", grid_ridge.best_params_)
# Out:
# Best parameters for Ridge: {'alpha': 1.0}

# %% [markdown]
# Lasso Regression

# %%
lasso = Lasso()

param_lasso = {
    'alpha': [0.01, 0.1, 1.0, 10.0]
}

grid_lasso = GridSearchCV(lasso, param_lasso, cv=5)
grid_lasso.fit(X_train, y_train)

print("Best parameters for Lasso:", grid_lasso.best_params_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.402e+14, tolerance: 1.779e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.715e+14, tolerance: 2.004e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.574e+14, tolerance: 1.866e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.748e+14, tolerance: 1.966e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.744e+14, tolerance: 1.978e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.402e+14, tolerance: 1.779e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.715e+14, tolerance: 2.004e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.574e+14, tolerance: 1.866e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.748e+14, tolerance: 1.966e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.744e+14, tolerance: 1.978e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.402e+14, tolerance: 1.779e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.715e+14, tolerance: 2.004e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.574e+14, tolerance: 1.866e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.749e+14, tolerance: 1.966e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.744e+14, tolerance: 1.978e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.404e+14, tolerance: 1.779e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.717e+14, tolerance: 2.004e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.576e+14, tolerance: 1.866e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.751e+14, tolerance: 1.966e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.746e+14, tolerance: 1.978e+11
#   model = cd_fast.enet_coordinate_descent(
# Best parameters for Lasso: {'alpha': 10.0}
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.304e+14, tolerance: 2.398e+11
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Compare the models

# %%
models = {
    'KNN': grid_knn.best_estimator_,
    'Random Forest': grid_rf.best_estimator_,
    'Linear Regression': lr,
    'Ridge': grid_ridge.best_estimator_,
    'Lasso': grid_lasso.best_estimator_
}

for name, model in models.items():
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    print(f"{name} - RMSE: {rmse:.2f}, R²: {r2:.2f}")
# Out:
# KNN - RMSE: 236722.57, R²: 0.53
# Random Forest - RMSE: 150228.47, R²: 0.81
# Linear Regression - RMSE: 191872.40, R²: 0.69
# Ridge - RMSE: 191852.01, R²: 0.69
# Lasso - RMSE: 191865.23, R²: 0.69
